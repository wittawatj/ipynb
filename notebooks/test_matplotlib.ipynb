# %% [markdown]
# ## Playing with matplotlib

# %% [markdown]
# `%pylab` will populate the current scope with functions from numpy and matplotlib. `inline` allows the plots to be displayed directly in the notebook.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
X=[1,2,3];
Y=[4,6,5];
plot(X, Y, 'bo-')

# %%
plot(X, Y,  marker='o', linestyle='--', color='#ff2780', label='legend uses this');
legend(loc='lower left');

# %%
# change the fig size
fig = figure(figsize=(10, 5)); 
plot(X, Y)
xlabel('x axis', fontsize=20)
ylabel('y axis')
title('figure title')
xlim([1,4]);

# or fig.set_figheight(5) later
# Out:
# (1, 4)

# %%
#save figure. figsize affects the saved raster figure
fig.set_figwidth(20);
fig.set_figheight(10);
fig.savefig('testplot.png');
fig.savefig('testplot.eps');

# %%
# globally changing the font size
font = {'family' : 'monospace',
          'weight' : 'bold',
          'size'   : 15};
rc('font', **font);
rc('lines', linewidth=2);
# plot again
plot(X, Y);
title('some title')
xlabel('my x-axis')

# %% [markdown]
# ## Some matrix plot

# %%
A = np.random.rand(10,10)
plt.imshow(A)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x6aad6c8>

# %%
plt.imshow(A, interpolation='nearest')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x6d3eb90>
